# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Geospatial_dataset_PRJ.csv", encoding="latin1")

# %%
df.columns
# Out:
# Index(['ISO_Code', 'Country', 'Population', 'Blood_Group_O_Positive (%)',
#        'Blood_Group_A_Positive(%)', 'Blood_Group_B_Positive%',
#        'Blood_Group_AB_Positive (%)', 'Blood_Group_O_Negative( %)',
#        'Blood_Group_A_Negative( %)', 'Blood_Group_B_Negative (%)',
#        'Blood_Group_AB_Negative (%)', 'Centroid_Lat', 'Centroid_Lon',
#        'Area_sq_km', 'Pop_Density (per km²)', 'GDP_per_capita (USD)',
#        'Median_Age', 'Literacy_Rate (%)', 'Healthcare_Index',
#        'Urbanization(%) '],
#       dtype='object')

# %%
# Check for duplicates in ISO_Code and Country
duplicate_iso = df["ISO_Code"].duplicated().sum()
duplicate_country = df["Country"].duplicated().sum()

# Check for leading/trailing spaces or inconsistent casing
df["ISO_Code"] = df["ISO_Code"].str.strip().str.upper()
df["Country"] = df["Country"].str.strip().str.title()

# Verify uniqueness of ISO_Code
unique_iso_count = df["ISO_Code"].nunique()
total_iso_count = len(df["ISO_Code"])

# Display results
{
    "Duplicate_ISO_Codes": duplicate_iso,
    "Duplicate_Country_Names": duplicate_country,
    "Unique_ISO_Codes": unique_iso_count,
    "Total_Records": total_iso_count,
}
# Out:
# {'Duplicate_ISO_Codes': 0,
#  'Duplicate_Country_Names': 0,
#  'Unique_ISO_Codes': 126,
#  'Total_Records': 126}

# %%
df['O_Positive_to_Negative_Ratio'] = df['Blood_Group_O_Positive (%)'] / df['Blood_Group_O_Negative( %)']
df['A_Positive_to_Negative_Ratio'] = df['Blood_Group_A_Positive(%)'] / df['Blood_Group_A_Negative( %)']
df['B_Positive_to_Negative_Ratio'] = df['Blood_Group_B_Positive%'] / df['Blood_Group_B_Negative (%)']
df['AB_Positive_to_Negative_Ratio'] = df['Blood_Group_AB_Positive (%)'] / df['Blood_Group_AB_Negative (%)']

# %%
df['O_Positive_PerCapita'] = df['Blood_Group_O_Positive (%)'] * df['Population'] / 100
df['A_Positive_PerCapita'] = df['Blood_Group_A_Positive(%)'] * df['Population'] / 100
df['B_Positive_PerCapita'] = df['Blood_Group_B_Positive%'] * df['Population'] / 100
df['AB_Positive_PerCapita'] = df['Blood_Group_AB_Positive (%)'] * df['Population'] / 100
df['O_Negative_PerCapita'] = df['Blood_Group_O_Negative( %)'] * df['Population'] / 100
df['A_Negative_PerCapita'] = df['Blood_Group_A_Negative( %)'] * df['Population'] / 100
df['B_Negative_PerCapita'] = df['Blood_Group_B_Negative (%)'] * df['Population'] / 100
df['AB_Negative_PerCapita'] = df['Blood_Group_AB_Negative (%)'] * df['Population'] / 100

# %%
df['Total_Positive_Percentage'] = df['Blood_Group_O_Positive (%)'] + df['Blood_Group_A_Positive(%)'] + df['Blood_Group_B_Positive%'] + df['Blood_Group_AB_Positive (%)']

# %%
df['Total_Negative_Percentage'] = df['Blood_Group_O_Negative( %)'] + df['Blood_Group_A_Negative( %)'] + df['Blood_Group_B_Negative (%)'] + df['Blood_Group_AB_Negative (%)']

# %%
df['O_Positive_vs_Total'] = df['Blood_Group_O_Positive (%)'] / df['Total_Positive_Percentage']
df['A_Positive_vs_Total'] = df['Blood_Group_A_Positive(%)'] / df['Total_Positive_Percentage']
df['B_Positive_vs_Total'] = df['Blood_Group_B_Positive%'] / df['Total_Positive_Percentage']
df['AB_Positive_vs_Total'] = df['Blood_Group_AB_Positive (%)'] / df['Total_Positive_Percentage']

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Select the numerical columns you want to standardize
cols_to_standardize = ['Population', 'Blood_Group_O_Positive (%)', 'Blood_Group_A_Positive(%)',
                       'Blood_Group_B_Positive%', 'Blood_Group_AB_Positive (%)', 'Blood_Group_O_Negative( %)', 
                       'Blood_Group_A_Negative( %)', 'Blood_Group_B_Negative (%)', 'Blood_Group_AB_Negative (%)']

# Fit and transform the selected columns
df[cols_to_standardize] = scaler.fit_transform(df[cols_to_standardize])

# %%
# Check for missing values in the dataset
df.isnull().sum()
# Out:
# ISO_Code                              0
# Country                               0
# Population                            0
# Blood_Group_O_Positive (%)            0
# Blood_Group_A_Positive(%)             0
# Blood_Group_B_Positive%               0
# Blood_Group_AB_Positive (%)           1
# Blood_Group_O_Negative( %)            1
# Blood_Group_A_Negative( %)            1
# Blood_Group_B_Negative (%)            1
# Blood_Group_AB_Negative (%)           1
# Centroid_Lat                          0
# Centroid_Lon                          0
# Area_sq_km                            0
# Pop_Density (per km²)                 0
# GDP_per_capita (USD)                126
# Median_Age                            0
# Literacy_Rate (%)                     0
# Healthcare_Index                      0
# Urbanization(%)                       0
# O_Positive_to_O_Negative_Ratio        1
# A_Positive_to_A_Negative_Ratio        1
# B_Positive_to_B_Negative_Ratio        1
# AB_Positive_to_AB_Negative_Ratio      2
# O_Positive_Per_Capita                 0
# A_Positive_Per_Capita                 0
# B_Positive_Per_Capita                 0
# AB_Positive_Per_Capita                1
# GDP_Per_Capita_Per_Density          126
# Healthcare_Index_Per_Capita           0
# O_Positive_to_Negative_Ratio          1
# A_Positive_to_Negative_Ratio          1
# B_Positive_to_Negative_Ratio          1
# AB_Positive_to_Negative_Ratio         2
# O_Positive_PerCapita                  0
# A_Positive_PerCapita                  0
# B_Positive_PerCapita                  0
# AB_Positive_PerCapita                 1
# O_Negative_PerCapita                  1
# A_Negative_PerCapita                  1
# B_Negative_PerCapita                  1
# AB_Negative_PerCapita                 1
# Total_Positive_Percentage             1
# Total_Negative_Percentage             1
# O_Positive_vs_Total                   1
# A_Positive_vs_Total                   1
# B_Positive_vs_Total                   1
# AB_Positive_vs_Total                  1
# dtype: int64

# %%
# Impute missing values with the mean (for numerical columns)
df['Population'] = df['Population'].fillna(df['Population'].mean())

# Alternatively, impute with the median
df['Blood_Group_O_Positive (%)'] = df['Blood_Group_O_Positive (%)'].fillna(df['Blood_Group_O_Positive (%)'].median())

# %%
# Impute missing values in a categorical column with the mode
df['Blood_Group_A_Positive(%)'] = df['Blood_Group_A_Positive(%)'].fillna(df['Blood_Group_A_Positive(%)'].mode()[0])

# %%
# Forward fill missing values
df['Blood_Group_O_Positive (%)'] = df['Blood_Group_O_Positive (%)'].ffill()

# Backward fill missing values (if any are left after forward fill)
df['Blood_Group_O_Positive (%)'] = df['Blood_Group_O_Positive (%)'].bfill()

# Apply forward fill first, then backward fill for any remaining missing values
df['Blood_Group_O_Positive (%)'] = df['Blood_Group_O_Positive (%)'].ffill().bfill()

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate mean, median, and standard deviation for the numeric columns
mean_values = numeric_df.mean()
median_values = numeric_df.median()
std_values = numeric_df.std()

# Display the summary statistics
summary_stats = pd.DataFrame({
    'Mean': mean_values,
    'Median': median_values,
    'Standard Deviation': std_values
})

print(summary_stats)
# Out:
#                                           Mean        Median  \
# Population                        1.689042e-01 -2.957578e-05
# Blood_Group_O_Positive (%)        1.639518e-01  0.000000e+00
# Blood_Group_A_Positive(%)        -7.855393e-02  0.000000e+00
# Blood_Group_B_Positive%           1.038217e-01  0.000000e+00
# Blood_Group_AB_Positive (%)       1.102888e-01  0.000000e+00
# Blood_Group_O_Negative( %)       -1.160000e-03  0.000000e+00
# Blood_Group_A_Negative( %)        1.203840e-01  0.000000e+00
# Blood_Group_B_Negative (%)        4.494964e-02  0.000000e+00
# Blood_Group_AB_Negative (%)       7.650000e-02  0.000000e+00
# Centroid_Lat                      2.520135e+01  2.801500e+01
# Centroid_Lon                      2.663254e+01  2.297000e+01
# Pop_Density (per km²)             4.451270e+02  9.350000e+01
# GDP_per_capita (USD)                       NaN           NaN
# Median_Age                        3.121984e+01  3.000000e+01
# Literacy_Rate (%)                 9.219841e+01  9.500000e+01
# Healthcare_Index                  6.900794e+01  7.000000e+01
# Urbanization(%)                   6.830159e+01  6.500000e+01
# O_Positive_to_O_Negative_Ratio    3.901158e+01  1.011111e+01
# A_Positive_to_A_Negative_Ratio    6.212750e+01  9.935484e+00
# B_Positive_to_B_Negative_Ratio    5.667032e+01  1.040000e+01
# AB_Positive_to_AB_Negative_Ratio  5.205151e+01  1.095556e+01
# O_Positive_Per_Capita             1.483710e-05  2.972316e-06
# A_Positive_Per_Capita             1.363717e-05  1.885571e-06
# B_Positive_Per_Capita             4.964372e-06  9.660406e-07
# AB_Positive_Per_Capita            1.704216e-06  2.706993e-07
# GDP_Per_Capita_Per_Density                 NaN           NaN
# Healthcare_Index_Per_Capita       3.100988e-05  4.693677e-06
# O_Positive_to_Negative_Ratio      3.901158e+01  1.011111e+01
# A_Positive_to_Negative_Ratio      6.212750e+01  9.935484e+00
# B_Positive_to_Negative_Ratio      5.667032e+01  1.040000e+01
# AB_Positive_to_Negative_Ratio     5.205151e+01  1.095556e+01
# O_Positive_PerCapita              4.516162e+07  5.867046e+06
# A_Positive_PerCapita              3.247576e+07  3.918971e+06
# B_Positive_PerCapita              1.815341e+07  1.838550e+06
# AB_Positive_PerCapita             4.773737e+06  5.662403e+05
# O_Negative_PerCapita              1.045364e+07  4.468098e+05
# A_Negative_PerCapita              6.172512e+06  3.342999e+05
# B_Negative_PerCapita              1.901621e+06  1.532718e+05
# AB_Negative_PerCapita             2.238100e+05  4.227746e+04
# Total_Positive_Percentage         9.044456e+01  9.064000e+01
# Total_Negative_Percentage         9.510960e+00  9.300000e+00
# O_Positive_vs_Total               4.454082e-01  4.299176e-01
# A_Positive_vs_Total               3.269837e-01  3.269556e-01
# B_Positive_vs_Total               1.767930e-01  1.705882e-01
# AB_Positive_vs_Total              5.081519e-02  4.714912e-02
#
#                                   Standard Deviation
# Population                              4.764199e-01
# Blood_Group_O_Positive (%)              7.013561e-01
# Blood_Group_A_Positive(%)               6.771377e-01
# Blood_Group_B_Positive%                 6.668559e-01
# Blood_Group_AB_Positive (%)             6.068386e-01
# Blood_Group_O_Negative( %)              7.463999e-01
# Blood_Group_A_Negative( %)              5.098396e-01
# Blood_Group_B_Negative (%)              6.189915e-01
# Blood_Group_AB_Negative (%)             4.717861e-01
# Centroid_Lat                            2.432321e+01
# Centroid_Lon                            6.093538e+01
# Pop_Density (per km²)                   2.094645e+03
# GDP_per_capita (USD)                             NaN
# Median_Age                              7.783244e+00
# Literacy_Rate (%)                       8.710472e+00
# Healthcare_Index                        1.152978e+01
# Urbanization(%)                         1.552663e+01
# O_Positive_to_O_Negative_Ratio          8.536245e+01
# A_Positive_to_A_Negative_Ratio          2.459163e+02
# B_Positive_to_B_Negative_Ratio          2.244746e+02
# AB_Positive_to_AB_Negative_Ratio        1.275222e+02
# O_Positive_Per_Capita                   7.852727e-05
# A_Positive_Per_Capita                   8.470085e-05
# B_Positive_Per_Capita                   2.325706e-05
# AB_Positive_Per_Capita                  9.228081e-06
# GDP_Per_Capita_Per_Density                       NaN
# Healthcare_Index_Per_Capita             1.838389e-04
# O_Positive_to_Negative_Ratio            8.536245e+01
# A_Positive_to_Negative_Ratio            2.459163e+02
# B_Positive_to_Negative_Ratio            2.244746e+02
# AB_Positive_to_Negative_Ratio           1.275222e+02
# O_Positive_PerCapita                    2.706076e+08
# A_Positive_PerCapita                    1.929284e+08
# B_Positive_PerCapita                    7.628681e+07
# AB_Positive_PerCapita                   1.960154e+07
# O_Negative_PerCapita                    9.797010e+07
# A_Negative_PerCapita                    5.627445e+07
# B_Negative_PerCapita                    1.407690e+07
# AB_Negative_PerCapita                   6.751861e+05
# Total_Positive_Percentage               6.279849e+00
# Total_Negative_Percentage               6.130908e+00
# O_Positive_vs_Total                     1.000326e-01
# A_Positive_vs_Total                     8.453017e-02
# B_Positive_vs_Total                     7.405940e-02
# AB_Positive_vs_Total                    2.404367e-02

# %%
# Get summary statistics for all numeric columns
numeric_summary = df.describe()

print(numeric_summary)
# Out:
#        Population  Blood_Group_O_Positive (%)  Blood_Group_A_Positive(%)  \
# count  126.000000                  126.000000                 126.000000
# mean     0.168904                    0.163952                  -0.078554
# std      0.476420                    0.701356                   0.677138
# min     -0.460048                   -0.779037                  -1.660182
# 25%     -0.208112                   -0.378541                  -0.584955
# 50%     -0.000030                    0.000000                   0.000000
# 75%      0.472248                    0.621459                   0.415045
# max      1.837091                    2.620397                   1.691310
#
#        Blood_Group_B_Positive%  Blood_Group_AB_Positive (%)  \
# count               126.000000                   125.000000
# mean                  0.103822                     0.110289
# std                   0.666856                     0.606839
# min                  -0.906126                    -0.989305
# 25%                  -0.467166                    -0.443850
# 50%                   0.000000                     0.000000
# 75%                   0.532834                     0.556150
# max                   1.921551                     1.903743
#
#        Blood_Group_O_Negative( %)  Blood_Group_A_Negative( %)  \
# count                   125.00000                  125.000000
# mean                     -0.00116                    0.120384
# std                       0.74640                    0.509840
# min                      -1.06000                   -0.556000
# 25%                      -0.57500                   -0.358000
# 50%                       0.00000                    0.000000
# 75%                       0.42500                    0.642000
# max                       2.45000                    1.062000
#
#        Blood_Group_B_Negative (%)  Blood_Group_AB_Negative (%)  Centroid_Lat  \
# count                  125.000000                   125.000000    126.000000
# mean                     0.044950                     0.076500     25.201349
# std                      0.618991                     0.471786     24.323213
# min                     -0.928058                    -0.487500    -41.280000
# 25%                     -0.496403                    -0.375000      9.562500
# 50%                      0.000000                     0.000000     28.015000
# 75%                      0.503597                     0.625000     44.830000
# max                      1.316547                     1.000000     64.960000
#
#        ...  O_Negative_PerCapita  A_Negative_PerCapita  B_Negative_PerCapita  \
# count  ...          1.250000e+02          1.250000e+02          1.250000e+02
# mean   ...          1.045364e+07          6.172512e+06          1.901621e+06
# std    ...          9.797010e+07          5.627445e+07          1.407690e+07
# min    ...          5.144538e+02          3.429692e+02          3.429692e+02
# 25%    ...          1.471875e+05          1.127470e+05          5.541204e+04
# 50%    ...          4.468098e+05          3.342999e+05          1.532718e+05
# 75%    ...          1.175067e+06          7.876743e+05          4.005395e+05
# max    ...          1.095972e+09          6.296009e+08          1.554570e+08
#
#        AB_Negative_PerCapita  Total_Positive_Percentage  \
# count           1.250000e+02                 125.000000
# mean            2.238100e+05                  90.444560
# std             6.751861e+05                   6.279849
# min             8.574230e+01                  75.000000
# 25%             1.163991e+04                  85.000000
# 50%             4.227746e+04                  90.640000
# 75%             1.068105e+05                  96.000000
# max             6.428786e+06                 101.200000
#
#        Total_Negative_Percentage  O_Positive_vs_Total  A_Positive_vs_Total  \
# count                 125.000000           125.000000           125.000000
# mean                    9.510960             0.445408             0.326984
# std                     6.130908             0.100033             0.084530
# min                     0.150000             0.272317             0.144928
# 25%                     4.100000             0.364706             0.255000
# 50%                     9.300000             0.429918             0.326956
# 75%                    15.000000             0.502446             0.400000
# max                    24.210000             0.776398             0.498385
#
#        B_Positive_vs_Total  AB_Positive_vs_Total
# count           125.000000            125.000000
# mean              0.176793              0.050815
# std               0.074059              0.024044
# min               0.052160              0.005176
# 25%               0.113402              0.030270
# 50%               0.170588              0.047149
# 75%               0.229167              0.070588
# max               0.369961              0.113541
#
# [8 rows x 45 columns]

# %%
import matplotlib.pyplot as plt

# Plot a histogram for 'Blood_Group_O_Positive (%)'
df['Blood_Group_O_Positive (%)'].hist(bins=20, edgecolor='black')
plt.title('Distribution of Blood Group O Positive (%)')
plt.xlabel('Percentage')
plt.ylabel('Frequency')
plt.show()

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate mean, median, and standard deviation for the numeric columns
mean_values = numeric_df.mean()
median_values = numeric_df.median()
std_values = numeric_df.std()

# Display the summary statistics
summary_stats = pd.DataFrame({
    'Mean': mean_values,
    'Median': median_values,
    'Standard Deviation': std_values
})

print(summary_stats)
# Out:
#                                           Mean        Median  \
# Population                        1.689042e-01 -2.957578e-05
# Blood_Group_O_Positive (%)        1.639518e-01  0.000000e+00
# Blood_Group_A_Positive(%)        -7.855393e-02  0.000000e+00
# Blood_Group_B_Positive%           1.038217e-01  0.000000e+00
# Blood_Group_AB_Positive (%)       1.102888e-01  0.000000e+00
# Blood_Group_O_Negative( %)       -1.160000e-03  0.000000e+00
# Blood_Group_A_Negative( %)        1.203840e-01  0.000000e+00
# Blood_Group_B_Negative (%)        4.494964e-02  0.000000e+00
# Blood_Group_AB_Negative (%)       7.650000e-02  0.000000e+00
# Centroid_Lat                      2.520135e+01  2.801500e+01
# Centroid_Lon                      2.663254e+01  2.297000e+01
# Pop_Density (per km²)             4.451270e+02  9.350000e+01
# GDP_per_capita (USD)                       NaN           NaN
# Median_Age                        3.121984e+01  3.000000e+01
# Literacy_Rate (%)                 9.219841e+01  9.500000e+01
# Healthcare_Index                  6.900794e+01  7.000000e+01
# Urbanization(%)                   6.830159e+01  6.500000e+01
# O_Positive_to_O_Negative_Ratio    3.901158e+01  1.011111e+01
# A_Positive_to_A_Negative_Ratio    6.212750e+01  9.935484e+00
# B_Positive_to_B_Negative_Ratio    5.667032e+01  1.040000e+01
# AB_Positive_to_AB_Negative_Ratio  5.205151e+01  1.095556e+01
# O_Positive_Per_Capita             1.483710e-05  2.972316e-06
# A_Positive_Per_Capita             1.363717e-05  1.885571e-06
# B_Positive_Per_Capita             4.964372e-06  9.660406e-07
# AB_Positive_Per_Capita            1.704216e-06  2.706993e-07
# GDP_Per_Capita_Per_Density                 NaN           NaN
# Healthcare_Index_Per_Capita       3.100988e-05  4.693677e-06
# O_Positive_to_Negative_Ratio      3.901158e+01  1.011111e+01
# A_Positive_to_Negative_Ratio      6.212750e+01  9.935484e+00
# B_Positive_to_Negative_Ratio      5.667032e+01  1.040000e+01
# AB_Positive_to_Negative_Ratio     5.205151e+01  1.095556e+01
# O_Positive_PerCapita              4.516162e+07  5.867046e+06
# A_Positive_PerCapita              3.247576e+07  3.918971e+06
# B_Positive_PerCapita              1.815341e+07  1.838550e+06
# AB_Positive_PerCapita             4.773737e+06  5.662403e+05
# O_Negative_PerCapita              1.045364e+07  4.468098e+05
# A_Negative_PerCapita              6.172512e+06  3.342999e+05
# B_Negative_PerCapita              1.901621e+06  1.532718e+05
# AB_Negative_PerCapita             2.238100e+05  4.227746e+04
# Total_Positive_Percentage         9.044456e+01  9.064000e+01
# Total_Negative_Percentage         9.510960e+00  9.300000e+00
# O_Positive_vs_Total               4.454082e-01  4.299176e-01
# A_Positive_vs_Total               3.269837e-01  3.269556e-01
# B_Positive_vs_Total               1.767930e-01  1.705882e-01
# AB_Positive_vs_Total              5.081519e-02  4.714912e-02
#
#                                   Standard Deviation
# Population                              4.764199e-01
# Blood_Group_O_Positive (%)              7.013561e-01
# Blood_Group_A_Positive(%)               6.771377e-01
# Blood_Group_B_Positive%                 6.668559e-01
# Blood_Group_AB_Positive (%)             6.068386e-01
# Blood_Group_O_Negative( %)              7.463999e-01
# Blood_Group_A_Negative( %)              5.098396e-01
# Blood_Group_B_Negative (%)              6.189915e-01
# Blood_Group_AB_Negative (%)             4.717861e-01
# Centroid_Lat                            2.432321e+01
# Centroid_Lon                            6.093538e+01
# Pop_Density (per km²)                   2.094645e+03
# GDP_per_capita (USD)                             NaN
# Median_Age                              7.783244e+00
# Literacy_Rate (%)                       8.710472e+00
# Healthcare_Index                        1.152978e+01
# Urbanization(%)                         1.552663e+01
# O_Positive_to_O_Negative_Ratio          8.536245e+01
# A_Positive_to_A_Negative_Ratio          2.459163e+02
# B_Positive_to_B_Negative_Ratio          2.244746e+02
# AB_Positive_to_AB_Negative_Ratio        1.275222e+02
# O_Positive_Per_Capita                   7.852727e-05
# A_Positive_Per_Capita                   8.470085e-05
# B_Positive_Per_Capita                   2.325706e-05
# AB_Positive_Per_Capita                  9.228081e-06
# GDP_Per_Capita_Per_Density                       NaN
# Healthcare_Index_Per_Capita             1.838389e-04
# O_Positive_to_Negative_Ratio            8.536245e+01
# A_Positive_to_Negative_Ratio            2.459163e+02
# B_Positive_to_Negative_Ratio            2.244746e+02
# AB_Positive_to_Negative_Ratio           1.275222e+02
# O_Positive_PerCapita                    2.706076e+08
# A_Positive_PerCapita                    1.929284e+08
# B_Positive_PerCapita                    7.628681e+07
# AB_Positive_PerCapita                   1.960154e+07
# O_Negative_PerCapita                    9.797010e+07
# A_Negative_PerCapita                    5.627445e+07
# B_Negative_PerCapita                    1.407690e+07
# AB_Negative_PerCapita                   6.751861e+05
# Total_Positive_Percentage               6.279849e+00
# Total_Negative_Percentage               6.130908e+00
# O_Positive_vs_Total                     1.000326e-01
# A_Positive_vs_Total                     8.453017e-02
# B_Positive_vs_Total                     7.405940e-02
# AB_Positive_vs_Total                    2.404367e-02

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv("Geospatial_dataset_PRJ.csv", encoding="latin1")

# Select only numeric columns (to avoid string/object types in correlation)
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5,
    cbar_kws={"shrink": 0.8}
)
plt.title('Correlation Heatmap of Blood Group Percentages and Public Health Indicators')
plt.tight_layout()
plt.show()

# %%
pair_plot_columns = ['Blood_Group_O_Positive (%)', 'Blood_Group_A_Positive(%)', 'Blood_Group_B_Positive%', 'Blood_Group_AB_Positive (%)', 'Population']  

# Plot the pair plot
sns.pairplot(df[pair_plot_columns], diag_kind='kde', plot_kws={'alpha': 0.7})
plt.suptitle('Pair Plot of Blood Group Percentages and Public Health Indicators', y=1.02)
plt.show()

# %%
columns_to_include = [
    'Population',
    'GDP_per_capita (USD)',
    'Median_Age',
    'Literacy_Rate (%)',
    'Healthcare_Index',
    'Urbanization(%) ',
    'Pop_Density (per km²)',
    'Blood_Group_O_Positive (%)',
    'Blood_Group_A_Positive(%)',
    'Blood_Group_B_Positive%',
    'Blood_Group_AB_Positive (%)'
]

numeric_columns = df[columns_to_include].select_dtypes(include=['float64', 'int64'])

# Correlation matrix
correlation_with_blood_groups = numeric_columns.corr()

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_with_blood_groups, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Between Blood Groups and Public Health Indicators')
plt.tight_layout()
plt.show()
